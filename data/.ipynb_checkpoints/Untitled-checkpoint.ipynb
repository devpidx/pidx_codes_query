# %%
import pandas as pd

# %%
data = pd.read_excel("PIDX-ProductCodes-08_10_2021.xlsx")
data.head(40)
# Out:
#    Code 1                Product definition 2               Description 3  \
# 0     A20                   AVIATION GASOLINE                         NaN
# 1     A21  Unbranded Aviation Gasoline 100/LL           AVIATION GASOLINE
# 2     A25                   AVIATION GASOLINE                         NaN
# 3     B00                        FUEL ETHANOL  ALTERNATIVE FUEL - Ed79-83
# 4     B01                        FUEL ETHANOL     ALTERNATIVE FUEL - Ed85
# 5     B02                        FUEL ETHANOL     ALTERNATIVE FUEL - Ed80
# 6     B03                        FUEL ETHANOL     ALTERNATIVE FUEL - Ed75
# 7     B04                        FUEL ETHANOL     ALTERNATIVE FUEL - Ed70
# 8     B05                        FUEL ETHANOL     ALTERNATIVE FUEL - Ed85
# 9     B06                        FUEL ETHANOL     ALTERNATIVE FUEL - Ed80
# 10    B07                        FUEL ETHANOL     ALTERNATIVE FUEL - Ed75
# 11    B08                        FUEL ETHANOL    ALTERNATIVE FUEL - Ed30
# ...

# %%
data.columns
# Out:
# Index(['Code 1', 'Product definition 2', 'Description 3', 'Cetane/octane 4',
#        'Oxygenated/rbob type 5', 'Oxygenate percent % v 6', 'Additized 7',
#        'Rvp percentage 8', 'Regulatory oxy % 9', 'Voc 10',
#        'Fungible/segre (f/s) 11', 'Dyes 12', 'Sulphur content 13', 'Am', 'M1',
#        'M2', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10', 'M11', 'M12',
#        'Comments 14', 'State code 15', 'Requester 16', 'Company 17',
#        'Date code assigned 18'],
#       dtype='object')

# %%
data.drop(columns=['Additized 7', 'Rvp percentage 8',
       'Regulatory oxy % 9', 'Voc 10', 'Fungible/segre (f/s) 11', 'Dyes 12', 'Rvp percentage 8', 'Fungible/segre (f/s) 11', 'Dyes 12', 'Sulphur content 13', 'Am', 'M1',
       'M2', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10', 'M11', 'M12', 'State code 15', 'Company 17'])
# Out:
#      Code 1                Product definition 2  \
# 0       A20                   AVIATION GASOLINE
# 1       A21  Unbranded Aviation Gasoline 100/LL
# 2       A25                   AVIATION GASOLINE
# 3       B00                        FUEL ETHANOL
# 4       B01                        FUEL ETHANOL
# ...     ...                                 ...
# 3668     YS                             ASPHALT
# 3669     YT                             ASPHALT
# 3670     YU                             ASPHALT
# 3671     YV                             ASPHALT
# 3672    ZZZ          NO LOAD, RESERVED FOR TABS
#
#                                 Description 3 Cetane/octane 4  \
# 0                                         NaN             NaN
# 1                           AVIATION GASOLINE             NaN
# 2                                         NaN             NaN
# 3                  ALTERNATIVE FUEL - Ed79-83             NaN
# 4                     ALTERNATIVE FUEL - Ed85             NaN
# ...
